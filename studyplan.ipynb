# %% [markdown]
# # books

# %% [markdown]
# - Introduction to Mathematical Statistics(hogg)
# - 통계학을 위한 행렬대수학(Shayle R.Searle) > 한글번역판도 괜찮음
# - A introduction to categorical data analysis(agresti) > 한글번역판도 괜찮다
# - 데이터분석 전문가를 위한 고급회귀분석(박성현 외 3인) >
# - R을 이용한 데이터마이닝(박창이) > ISLP같은 느낌
# - An Introduction to Statistical Learning with Python (James, Witten, Hastie, Tibshirani) > ISLP
# - elements of statistical learning(Hastie, Friedman, Tibshirani) > ESL
# - pattern recognition and machine learning(Bishop) > PRML
# - Deep learning(goodfellow)
# - statistical learning with sparsity the lasso and generalizations(Tibshirani, Hastie, Wainwright)
# - probabilistic machine learning an introduction(murphy)

# %% [markdown]
# # Blogs

# %% [markdown]
# - https://taemobang.com (방태모)

# %% [markdown]
# #
#
# ##### 1
# - Introduction to Mathematical Statistics(hogg)
# - 통계학을 위한 행렬대수학(Shayle R.Searle) > 한글번역판도 괜찮음
# - IRT: Embretson, S.E., & Reise, S.P. (2000). Item Response Theory for Psychologists\
#     Baker, F.B., & Kim, S.-H. (Eds.). (2004). Item Response Theory: Parameter Estimation Techniques\
#     de Ayala, R. J. (2022). The theory and practice of item response theory
#
# ##### 2
# - A introduction to categorical data analysis(agresti) > 한글번역판도 괜찮다
# - 데이터분석 전문가를 위한 고급회귀분석(박성현 외 3인)
# - statistical rethinking()
# - Bayesian Data Analysis(gelman)
# - 비모수 통계학 with R(정성교)
#
# #####
# - An Introduction to Statistical Learning with Python (James, Witten, Hastie, Tibshirani) > ISLP
